# %%
import bs4, re, requests
from bs4 import BeautifulSoup

# %%
req = requests.get('https://killpls.me/')
    
soup = BeautifulSoup(req.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Килл Ми Плз: Жизнь. Вид сзади.</title>
# <link href="http://killpls.me/rss/" rel="alternate" title="KillMePls RSS" type="application/rss+xml"/>
# <!-- Bootstrap -->
# <link href="/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/style.css" rel="stylesheet"/>
# <meta content="5f2e8fb6fcccffa6b083f5b4" name="verify-reformal"/>
# <meta content="634071205,795465180" property="fb:admins"/>
# <meta content="276964729087362" property="fb:app_id"/>
# <script charset="utf-8" src="//yandex.st/share/share.js" type="text/javascript"></script>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
# ...

# %%
cont=soup.find('div', {'class' : 'col-xs-12', 'style' : 'margin:0.5em 0;line-height:1.785em'})
type(cont.contents[1])
# Out:
# bs4.element.Tag

# %%
fullContent=''
for para in cont:    
    content=str(para).strip()
    fullContent+=content
re.search('лишний вес', fullContent)
# Out:
# <_sre.SRE_Match object; span=(22, 32), match='лишний вес'>

# %%
listOfStories = []
for i in range(24333):
    listOfStories.append('https://killpls.me/story/' + str(i))

# %%
listOfStories
# Out:
# ['https://killpls.me/story/0',
#  'https://killpls.me/story/1',
#  'https://killpls.me/story/2',
#  'https://killpls.me/story/3',
#  'https://killpls.me/story/4',
#  'https://killpls.me/story/5',
#  'https://killpls.me/story/6',
#  'https://killpls.me/story/7',
#  'https://killpls.me/story/8',
#  'https://killpls.me/story/9',
#  'https://killpls.me/story/10',
#  'https://killpls.me/story/11',
#  'https://killpls.me/story/12',
#  'https://killpls.me/story/13',
#  'https://killpls.me/story/14',
#  'https://killpls.me/story/15',
#  'https://killpls.me/story/16',
#  'https://killpls.me/story/17',
#  'https://killpls.me/story/18',
#  'https://killpls.me/story/19',
#  'https://killpls.me/story/20',
#  'https://killpls.me/story/21',
#  'https://killpls.me/story/22',
#  'https://killpls.me/story/23',
#  'https://killpls.me/story/24',
#  'https://killpls.me/story/25',
#  'https://killpls.me/story/26',
#  'https://killpls.me/story/27',
#  'https://killpls.me/story/28',
# ...

# %%
fullContent=''
for link in listOfStories:
    req = requests.get(link)
    soup = BeautifulSoup(req.text, 'lxml')
    cont=soup.find('div', {'class' : 'col-xs-12', 'style' : 'margin:0.5em 0;line-height:1.785em'})
 
    print(link+'\n')
    for para in cont:    
        content=str(para).strip()
        fullContent+=content
    
        if (re.search('Ушел от девушки, показалось,', content) is not None):
            print (re.search('Ушел от девушки, показалось,', content))
            break
# Out:
# https://killpls.me/story/0
#
# https://killpls.me/story/1
#
# https://killpls.me/story/2
#
# https://killpls.me/story/3
#
# https://killpls.me/story/4
#
# https://killpls.me/story/5
#
# https://killpls.me/story/6
#
# https://killpls.me/story/7
#
# https://killpls.me/story/8
#
# https://killpls.me/story/9
#
# https://killpls.me/story/10
#
# https://killpls.me/story/11
#
# https://killpls.me/story/12
#
# https://killpls.me/story/13
#
# https://killpls.me/story/14
#
# https://killpls.me/story/15
#
# https://killpls.me/story/16
#
# https://killpls.me/story/17
#
# https://killpls.me/story/18
#
# https://killpls.me/story/19
#
# https://killpls.me/story/20
#
# https://killpls.me/story/21
#
# https://killpls.me/story/22
#
# https://killpls.me/story/23
#
# https://killpls.me/story/24
#
# https://killpls.me/story/25
#
# https://killpls.me/story/26
#
# https://killpls.me/story/27
#
# https://killpls.me/story/28
#
# https://killpls.me/story/29
#
# https://killpls.me/story/30
#
# ...

# %%
def getStoryText(link):
    fullStory=[]
    page = requests.get(link)
    soup = BeautifulSoup(page.text,'lxml')
    snippet=soup.find('div', {'class' : "col-xs-12", 'style' : "margin:0.5em 0;line-height:1.785em"})
    for part in snippet.contents:
        if part.string is not None:       
            fullStory.append(part.string.strip())
    fullStoryStr=''.join(fullStory)
    print(fullStoryStr)
    with open('stories.txt', 'a') as file:
        file.write(fullStoryStr+ "\n")

    return "ok"
getStoryText('https://killpls.me/story/24317')

# %%
for link in storiesLinks:
    getStoryText(link)
